# %%
# %load_ext autoreload
# %autoreload 2

from cifar10 import cifar10_eval
from cifar10.cifar10_args import *

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=

Arguments.set_inference("resnet1")
print(Arguments.train_dir)
print(Arguments.eval_dir)
print(Arguments.checkpoint_dir)

cifar10_eval.evaluate()
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=
# /home/ipython/cnn-cifar10/tb_log/resnet1/train
# /home/ipython/cnn-cifar10/tb_log/resnet1/eval
# /home/ipython/cnn-cifar10/tb_log/resnet1/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet1/train/model.ckpt-1
# 2017-05-30 21:00:35.878020: precision @ 1 top1 = 0.105
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet1/train/model.ckpt-1674
# 2017-05-30 21:11:14.046932: precision @ 1 top1 = 0.284
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet1/train/model.ckpt-3541
# 2017-05-30 21:22:04.721039: precision @ 1 top1 = 0.335
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet1/train/model.ckpt-5254
# 2017-05-30 21:32:44.065382: precision @ 1 top1 = 0.509
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet1/train/model.ckpt-8822
# 2017-05-30 21:43:38.439546: precision @ 1 top1 = 0.673
