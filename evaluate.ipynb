# %%
# %load_ext autoreload
# %autoreload 2

from cifar10 import cifar10_eval
from cifar10.cifar10_args import *

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=

Arguments.set_model_folder("vggE")
print(Arguments.checkpoint_dir)

cifar10_eval.evaluate()
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:35:58.300853: precision @ 1 top1 = 0.099
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:37:37.103516: precision @ 1 top5 = 0.743
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:41:17.167756: precision @ 1 top1 = 0.098
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:43:59.800718: precision @ 1 top5 = 0.498
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:47:42.008346: precision @ 1 top1 = 0.097
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1
# 2017-05-26 15:50:26.750959: precision @ 1 top5 = 0.500
# 2017-05-26 15:54:11.650090: precision @ 1 top1 = 0.484
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1216
# 2017-05-26 15:56:54.607087: precision @ 1 top5 = 0.997
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-1216
# 2017-05-26 16:00:39.101622: precision @ 1 top1 = 0.484
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-2452
# 2017-05-26 16:03:22.211620: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-2452
# 2017-05-26 16:07:05.313263: precision @ 1 top1 = 0.749
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-2452
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-3636
# 2017-05-26 16:13:31.805036: precision @ 1 top1 = 0.801
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-3636
# 2017-05-26 16:16:14.307813: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-3636
# 2017-05-26 16:19:57.595487: precision @ 1 top1 = 0.801
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-4877
# 2017-05-26 16:22:42.704420: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-4877
# 2017-05-26 16:26:31.982714: precision @ 1 top1 = 0.836
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-4877
# 2017-05-26 16:29:22.433835: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-6064
# 2017-05-26 16:33:14.402809: precision @ 1 top1 = 0.861
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-6064
# 2017-05-26 16:36:06.565279: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-6064
# 2017-05-26 16:39:59.146971: precision @ 1 top1 = 0.859
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-7311
# 2017-05-26 16:42:51.956026: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-7311
# 2017-05-26 16:46:36.705184: precision @ 1 top1 = 0.867
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-7311
# 2017-05-26 16:49:19.685461: precision @ 1 top5 = 1.000
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-8503
# 2017-05-26 16:51:47.820395: precision @ 1 top1 = 0.876
# /home/ipython/cnn-cifar10/tb_log/vggE/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/vggE/train/model.ckpt-8503
