# %%
# %load_ext autoreload
# %autoreload 2

from cifar10 import cifar10_eval

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=

cifar10_eval.evaluate()
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-76892
# 2017-05-22 16:10:40.910246: precision @ 1 = 0.860
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-76892
# 2017-05-22 16:11:44.351855: precision @ 1 = 0.862
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-76892
# 2017-05-22 16:12:47.137545: precision @ 1 = 0.861
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-76892
# 2017-05-22 16:13:49.613478: precision @ 1 = 0.860
# 2017-05-22 16:14:52.714227: precision @ 1 = 0.861
# 2017-05-22 16:15:55.285170: precision @ 1 = 0.860
# 2017-05-22 16:16:58.266463: precision @ 1 = 0.860
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-76892
# 2017-05-22 16:18:01.361955: precision @ 1 = 0.860
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:20:06.565676: precision @ 1 = 0.865
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:21:09.111527: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:22:12.339582: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:23:15.426285: precision @ 1 = 0.865
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:24:18.193112: precision @ 1 = 0.865
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:25:21.629512: precision @ 1 = 0.865
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:26:24.752940: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-83727
# 2017-05-22 16:27:27.532492: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:28:30.702619: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:29:33.243746: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:30:36.079416: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:31:38.778649: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:32:41.190791: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:33:44.547622: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:34:47.325375: precision @ 1 = 0.866
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:35:50.135583: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# 2017-05-22 16:36:52.672635: precision @ 1 = 0.867
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-90503
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-97267
# /tmp/cifar10_train
# INFO:tensorflow:Restoring parameters from /tmp/cifar10_train/model.ckpt-97267
# 2017-05-22 16:40:02.318503: precision @ 1 = 0.867
