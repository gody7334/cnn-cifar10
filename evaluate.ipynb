# %%
# %load_ext autoreload
# %autoreload 2

from cifar10 import cifar10_eval
from cifar10.cifar10_args import *

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=

Arguments.set_inference("resnet5")
print(Arguments.train_dir)
print(Arguments.eval_dir)
print(Arguments.checkpoint_dir)

cifar10_eval.evaluate()
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=
# /home/ipython/cnn-cifar10/tb_log/resnet5/train
# /home/ipython/cnn-cifar10/tb_log/resnet5/eval
# /home/ipython/cnn-cifar10/tb_log/resnet5/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-47627
# 2017-06-06 20:24:18.943318: precision @ 1 top1 = 0.898
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-49215
# 2017-06-06 20:35:07.109540: precision @ 1 top1 = 0.897
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-50810
# 2017-06-06 20:45:55.284652: precision @ 1 top1 = 0.898
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-52400
# 2017-06-06 20:56:45.218954: precision @ 1 top1 = 0.896
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-53991
# 2017-06-06 21:07:32.550033: precision @ 1 top1 = 0.893
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-55614
# 2017-06-06 21:18:14.562961: precision @ 1 top1 = 0.895
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-57433
# 2017-06-06 21:29:02.822678: precision @ 1 top1 = 0.897
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-59137
# 2017-06-06 21:39:53.054027: precision @ 1 top1 = 0.897
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-60880
# 2017-06-06 21:50:38.897014: precision @ 1 top1 = 0.899
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-62595
# 2017-06-06 22:01:21.583074: precision @ 1 top1 = 0.898
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-64418
# 2017-06-06 22:12:02.993205: precision @ 1 top1 = 0.896
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-66192
# 2017-06-06 22:22:47.691679: precision @ 1 top1 = 0.895
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-67857
# 2017-06-06 22:33:39.954492: precision @ 1 top1 = 0.896
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-69465
# 2017-06-06 22:44:32.090689: precision @ 1 top1 = 0.895
