# %%
# %load_ext autoreload
# %autoreload 2

from cifar10 import cifar10_eval
from cifar10.cifar10_args import *

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=

Arguments.set_inference("resnet5")
print(Arguments.train_dir)
print(Arguments.eval_dir)
print(Arguments.checkpoint_dir)

cifar10_eval.evaluate()
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=
# /home/ipython/cnn-cifar10/tb_log/resnet5/train
# /home/ipython/cnn-cifar10/tb_log/resnet5/eval
# /home/ipython/cnn-cifar10/tb_log/resnet5/train
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-1
# 2017-06-06 15:42:40.819536: precision @ 1 top1 = 0.106
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-1822
# 2017-06-06 15:53:32.219639: precision @ 1 top1 = 0.715
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-3621
# 2017-06-06 16:04:28.992238: precision @ 1 top1 = 0.805
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-5414
# 2017-06-06 16:15:25.824057: precision @ 1 top1 = 0.831
# INFO:tensorflow:Restoring parameters from /home/ipython/cnn-cifar10/tb_log/resnet5/train/model.ckpt-7195
# 2017-06-06 16:26:27.046838: precision @ 1 top1 = 0.851
